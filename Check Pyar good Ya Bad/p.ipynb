# %%
import pandas as pd

rel_df = pd.read_csv("relationship_dataset_500.csv")
health_df = pd.read_csv("health_dataset.csv")

# Reset index to make sure rows align correctly
merge_data = pd.concat([rel_df.reset_index(drop=True), health_df.reset_index(drop=True)], axis=1)

print(merge_data)
# Out:
#   gender  respect  phone_call_time  communication  trust  avg_score status  \
# 0   Girl        3               10              2      7       5.50   Good
# 1    Boy        5                7              2      9       5.75   Good
# 2   Girl        7                8              6      3       6.00   Good
# 3   Girl        2                4              9      5       5.00   Good
# 4   Girl        4                1              3     10       4.50    Bad
#
#    relationship_years  Sleep_hour_health  mood_level_health  \
# 0                   1                  6                  8
# 1                   6                  9                  6
# 2                   3                  7                  9
# 3                   2                  9                  8
# 4                   4                  6                  9
#
#    stress_level_health exercise_health  water_intake_health food_health  \
# 0                    7             yes                    7         yes
# ...
